# %%
import pandas as pd
df=pd.read_csv('data.csv')

# %%
df
# Out:
#       StudentID  CGPA  Major Projects  Workshops/Certifications  \
# 0             1   7.5               1                         1
# 1             2   8.9               0                         3
# 2             3   7.3               1                         2
# 3             4   7.5               1                         1
# 4             5   8.3               1                         2
# ...         ...   ...             ...                       ...
# 9995       9996   7.5               1                         1
# 9996       9997   7.4               0                         1
# 9997       9998   8.4               1                         3
# 9998       9999   8.9               0                         3
# 9999      10000   8.4               0                         1
#
#       Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0                 1       6                         4.4         No        No
# ...

# %%
df=df.loc[:,~df.columns.str.contains('^Unnamed')]

# %%
df
# Out:
#       StudentID  CGPA  Major Projects  Workshops/Certifications  \
# 0             1   7.5               1                         1
# 1             2   8.9               0                         3
# 2             3   7.3               1                         2
# 3             4   7.5               1                         1
# 4             5   8.3               1                         2
# ...         ...   ...             ...                       ...
# 9995       9996   7.5               1                         1
# 9996       9997   7.4               0                         1
# 9997       9998   8.4               1                         3
# 9998       9999   8.9               0                         3
# 9999      10000   8.4               0                         1
#
#       Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0                 1       6                         4.4         No        No
# ...

# %%
df.dropna(axis=1)
# Out:
#       StudentID  CGPA  Major Projects  Workshops/Certifications  \
# 0             1   7.5               1                         1
# 1             2   8.9               0                         3
# 2             3   7.3               1                         2
# 3             4   7.5               1                         1
# 4             5   8.3               1                         2
# ...         ...   ...             ...                       ...
# 9995       9996   7.5               1                         1
# 9996       9997   7.4               0                         1
# 9997       9998   8.4               1                         3
# 9998       9999   8.9               0                         3
# 9999      10000   8.4               0                         1
#
#       Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0                 1       6                         4.4         No        No
# ...

# %%
dfa=df.to_numpy()

# %%
dfa
# Out:
# array([[1, 7.5, 1, ..., 61, 79, 'NotPlaced'],
#        [2, 8.9, 0, ..., 78, 82, 'Placed'],
#        [3, 7.3, 1, ..., 79, 80, 'NotPlaced'],
#        ...,
#        [9998, 8.4, 1, ..., 79, 81, 'Placed'],
#        [9999, 8.9, 0, ..., 71, 85, 'Placed'],
#        [10000, 8.4, 0, ..., 62, 66, 'NotPlaced']], dtype=object)

# %%
df['backlogs']=[0 for i in range(10000)]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12920\1631694311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['backlogs']=[0 for i in range(10000)]

# %%
df
# Out:
#       StudentID  CGPA  Major Projects  Workshops/Certifications  \
# 0             1   7.5               1                         1
# 1             2   8.9               0                         3
# 2             3   7.3               1                         2
# 3             4   7.5               1                         1
# 4             5   8.3               1                         2
# ...         ...   ...             ...                       ...
# 9995       9996   7.5               1                         1
# 9996       9997   7.4               0                         1
# 9997       9998   8.4               1                         3
# 9998       9999   8.9               0                         3
# 9999      10000   8.4               0                         1
#
#       Mini Projects  Skills  Communication Skill Rating Internship Hackathon  \
# 0                 1       6                         4.4         No        No
# ...

# %%
dfa=df.to_numpy()

# %%
dfa
# Out:
# array([[1, 7.5, 1, ..., 79, 'NotPlaced', 0],
#        [2, 8.9, 0, ..., 82, 'Placed', 0],
#        [3, 7.3, 1, ..., 80, 'NotPlaced', 0],
#        ...,
#        [9998, 8.4, 1, ..., 81, 'Placed', 0],
#        [9999, 8.9, 0, ..., 85, 'Placed', 0],
#        [10000, 8.4, 0, ..., 66, 'NotPlaced', 0]], dtype=object)

# %%
import random
for i in range(10000):
    if dfa[i][1]>8.5 and dfa[i][11]=='Placed':
        dfa[i][12]=0
    elif dfa[i][1]>7 and dfa[i][11]=='Placed':
        
        dfa[i][12]=random.choice([0,1])
    elif dfa[i][1]>8 and dfa[i][11]=='NotPlaced':
        dfa[i][12]=1
        
    elif dfa[i][1]>6 and dfa[i][11]=='NotPlaced':
        dfa[i][12]=random.choice([2,3,4])
    elif dfa[i][1]<7 and dfa[i][11]=='Placed':
        dfa[i][12]=random.choice([0,1,2])
    else:
        dfa[i][12]=random.choice([3,4,5,6,7])

# %%
dfa
# Out:
# array([[1, 7.5, 1, ..., 79, 'NotPlaced', 2],
#        [2, 8.9, 0, ..., 82, 'Placed', 0],
#        [3, 7.3, 1, ..., 80, 'NotPlaced', 2],
#        ...,
#        [9998, 8.4, 1, ..., 81, 'Placed', 0],
#        [9999, 8.9, 0, ..., 85, 'Placed', 0],
#        [10000, 8.4, 0, ..., 66, 'NotPlaced', 1]], dtype=object)

# %%
df=pd.DataFrame(dfa,columns=['StudentId','CGPA','Major Projects','Workshops/Certificatios','Mini Projects','Skills','Communication Skill Rating','Internship','Hackathon','12th Percentage','10th Percentage','PlacementStatus','backlogs'])

# %%
df
# Out:
#      StudentId CGPA Major Projects Workshops/Certificatios Mini Projects  \
# 0            1  7.5              1                       1             1
# 1            2  8.9              0                       3             2
# 2            3  7.3              1                       2             2
# 3            4  7.5              1                       1             2
# 4            5  8.3              1                       2             2
# ...        ...  ...            ...                     ...           ...
# 9995      9996  7.5              1                       1             2
# 9996      9997  7.4              0                       1             0
# 9997      9998  8.4              1                       3             0
# 9998      9999  8.9              0                       3             2
# 9999     10000  8.4              0                       1             1
#
#      Skills Communication Skill Rating Internship Hackathon 12th Percentage  \
# ...

# %%
x=df.drop(['PlacementStatus'],axis=1)

# %%
y=df['PlacementStatus']

# %%
x['PlacementStatus']=y.to_numpy()

# %%
x
# Out:
#      StudentId CGPA Major Projects Workshops/Certificatios Mini Projects  \
# 0            1  7.5              1                       1             1
# 1            2  8.9              0                       3             2
# 2            3  7.3              1                       2             2
# 3            4  7.5              1                       1             2
# 4            5  8.3              1                       2             2
# ...        ...  ...            ...                     ...           ...
# 9995      9996  7.5              1                       1             2
# 9996      9997  7.4              0                       1             0
# 9997      9998  8.4              1                       3             0
# 9998      9999  8.9              0                       3             2
# 9999     10000  8.4              0                       1             1
#
#      Skills Communication Skill Rating Internship Hackathon 12th Percentage  \
# ...

# %%
x.to_csv('data2.csv')

# %%
df=pd.read_csv('data2.csv')

# %%
df
# Out:
#       Unnamed: 0  StudentId  CGPA  Major Projects  Workshops/Certificatios  \
# 0              0          1   7.5               1                        1
# 1              1          2   8.9               0                        3
# 2              2          3   7.3               1                        2
# 3              3          4   7.5               1                        1
# 4              4          5   8.3               1                        2
# ...          ...        ...   ...             ...                      ...
# 9995        9995       9996   7.5               1                        1
# 9996        9996       9997   7.4               0                        1
# 9997        9997       9998   8.4               1                        3
# 9998        9998       9999   8.9               0                        3
# 9999        9999      10000   8.4               0                        1
#
# ...

# %%
df=df.loc[:,~df.columns.str.contains('^Unnamed')]

# %%
df
# Out:
#       StudentId  CGPA  Major Projects  Workshops/Certificatios  Mini Projects  \
# 0             1   7.5               1                        1              1
# 1             2   8.9               0                        3              2
# 2             3   7.3               1                        2              2
# 3             4   7.5               1                        1              2
# 4             5   8.3               1                        2              2
# ...         ...   ...             ...                      ...            ...
# 9995       9996   7.5               1                        1              2
# 9996       9997   7.4               0                        1              0
# 9997       9998   8.4               1                        3              0
# 9998       9999   8.9               0                        3              2
# 9999      10000   8.4               0                        1              1
#
# ...

# %%
df.to_csv('data3.csv')

# %%
x=pd.read_csv('data3.csv')

# %%
x
# Out:
#       Unnamed: 0  StudentId  CGPA  Major Projects  Workshops/Certificatios  \
# 0              0          1   7.5               1                        1
# 1              1          2   8.9               0                        3
# 2              2          3   7.3               1                        2
# 3              3          4   7.5               1                        1
# 4              4          5   8.3               1                        2
# ...          ...        ...   ...             ...                      ...
# 9995        9995       9996   7.5               1                        1
# 9996        9996       9997   7.4               0                        1
# 9997        9997       9998   8.4               1                        3
# 9998        9998       9999   8.9               0                        3
# 9999        9999      10000   8.4               0                        1
#
# ...

# %%
x=x.loc[:,~x.columns.str.contains('^Unnamed')]

# %%
x
# Out:
#       StudentId  CGPA  Major Projects  Workshops/Certificatios  Mini Projects  \
# 0             1   7.5               1                        1              1
# 1             2   8.9               0                        3              2
# 2             3   7.3               1                        2              2
# 3             4   7.5               1                        1              2
# 4             5   8.3               1                        2              2
# ...         ...   ...             ...                      ...            ...
# 9995       9996   7.5               1                        1              2
# 9996       9997   7.4               0                        1              0
# 9997       9998   8.4               1                        3              0
# 9998       9999   8.9               0                        3              2
# 9999      10000   8.4               0                        1              1
#
# ...

# %%
df=x

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

df.fillna(0,inplace=True)
x=df.drop(['StudentId','PlacementStatus'],axis=1)
y = df['PlacementStatus']
le = preprocessing.LabelEncoder()
x['Internship'] = le.fit_transform(x['Internship'])
x['Hackathon'] = le.fit_transform(x['Hackathon'])


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12920\2284097519.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(0,inplace=True)

# %%
x_train
# Out:
#       CGPA  Major Projects  Workshops/Certificatios  Mini Projects  Skills  \
# 1191   7.8               1                        2              1       7
# 4458   8.7               2                        2              2       9
# 1131   8.6               2                        3              2       9
# 9562   7.8               1                        1              0       6
# 6579   7.8               1                        2              1       7
# ...    ...             ...                      ...            ...     ...
# 350    7.5               1                        2              0       7
# 79     7.6               1                        2              1       7
# 8039   8.2               2                        3              2       8
# 6936   7.6               1                        2              0       6
# 5640   6.6               0                        2              1       6
#
# ...

# %%
y_train
# Out:
# 1191    NotPlaced
# 4458       Placed
# 1131       Placed
# 9562    NotPlaced
# 6579    NotPlaced
#           ...
# 350     NotPlaced
# 79      NotPlaced
# 8039       Placed
# 6936    NotPlaced
# 5640    NotPlaced
# Name: PlacementStatus, Length: 7000, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
classify= RandomForestClassifier(n_estimators= 10, criterion="entropy")
classify.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
ypred=classify.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_test,ypred)
# Out:
# 0.9326666666666666

# %%
confusion_matrix(ypred,y_test)
# Out:
# array([[1703,  131],
#        [  71, 1095]], dtype=int64)

# %%
classification_report(y_test,ypred)
# Out:
# '              precision    recall  f1-score   support\n\n   NotPlaced       0.93      0.96      0.94      1774\n      Placed       0.94      0.89      0.92      1226\n\n    accuracy                           0.93      3000\n   macro avg       0.93      0.93      0.93      3000\nweighted avg       0.93      0.93      0.93      3000\n'

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn=KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
ypred=knn.predict(x_test)

# %%
ypred
# Out:
# array(['NotPlaced', 'NotPlaced', 'NotPlaced', ..., 'Placed', 'NotPlaced',
#        'Placed'], dtype=object)

# %%
accuracy_score(y_test,ypred)
# Out:
# 0.868

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier(random_state=0)
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
ypred=dtc.predict(x_test)
ypred
# Out:
# array(['NotPlaced', 'NotPlaced', 'Placed', ..., 'Placed', 'NotPlaced',
#        'Placed'], dtype=object)

# %%
accuracy_score(y_test,ypred)
# Out:
# 0.9243333333333333
